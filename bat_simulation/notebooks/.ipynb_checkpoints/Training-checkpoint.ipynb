# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfs = []
for i in range(1,5):
    file_path='../speed_'+str(i)+'.csv'
    df = pd.read_csv(file_path)
    df.groupby('experiment')['reward'].sum().plot()
